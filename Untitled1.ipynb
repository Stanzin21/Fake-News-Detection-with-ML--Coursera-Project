# %% [markdown]
# <a href="https://colab.research.google.com/github/Stanzin21/Fake-News-Detection-with-ML--Coursera-Project/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import random

# %%
L=[]
for i in range(10000):
  a = random.randint(1,6)
  b = random.randint(1,6)
  L.append(a+b)

# %%
len(L)
# Out:
# 10000

# %%
L[:5]
# Out:
# [5, 10, 5, 8, 6]

# %%
s= (pd.Series(L).value_counts()/pd.Series(L).value_counts().sum()).sort_index()

# %%
s
# Out:
# 2     0.0278
# 3     0.0504
# 4     0.0824
# 5     0.1149
# 6     0.1422
# 7     0.1606
# 8     0.1440
# 9     0.1143
# 10    0.0825
# 11    0.0575
# 12    0.0234
# Name: count, dtype: float64

# %%
s.plot(kind='bar')
# Out:
# <Axes: >

# %%
import numpy as np
np.cumsum(s).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal

sample = normal(loc=50, scale=5, size=1000)

# %%
sample.mean()
# Out:
# np.float64(50.21778639820893)

# %%
plt.hist(sample,bins=10)
# Out:
# (array([  3.,  21.,  62., 146., 215., 248., 179.,  88.,  28.,  10.]),
#  array([33.80155073, 36.96558692, 40.12962312, 43.29365931, 46.45769551,
#         49.62173171, 52.7857679 , 55.9498041 , 59.11384029, 62.27787649,
#         65.44191268]),
#  <BarContainer object of 10 artists>)

# %%
sample_mean= sample.mean()
sample_std= sample.std()

# %%
from scipy.stats import norm
dist= norm(sample_mean,sample_std)

# %%
sample.max()
# Out:
# np.float64(65.44191268380948)

# %%
values= np.linspace(sample.min(),sample.max(),100)

# %%
probabilities= [dist.pdf(value) for value in values]

# %%
plt.hist(sample,bins=10, density=True)
plt.plot(values,probabilities)
